# %% [markdown]
# # ELKADY AUTO - Cars245 Scraper
# This notebook is a lightweight Colab launcher for the organized `cars245_scraper.py` script in this repository.

# %%
# !pip -q install -r requirements.txt

# %%
from cars245_scraper import scrape_part

PART_NUMBER = "04E 121 600 BE"
raw_df, clean_df = scrape_part(PART_NUMBER, max_products=20, output_dir="output")
clean_df.head(20)
